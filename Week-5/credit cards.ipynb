# %%
#read in the credit_cards.csv file
import pandas as pd
data = pd.read_csv('credit_cards.csv')
data
# Out:
#      Card Type Full Name      Issuing Bank       Card Number  \
# 0                   Visa             Chase  4431465245886276
# 1               Discover          Discover  6224764404044446
# 2    Japan Credit Bureau               JCB  3541789329050940
# 3       American Express  American Express   371306399244328
# 4                   Visa             Chase  4332985341176660
# ..                   ...               ...               ...
# 995  Japan Credit Bureau               JCB  3548795949760431
# 996  Japan Credit Bureau               JCB  3566452282997041
# 997  Japan Credit Bureau               JCB  3539269980463108
# 998             Discover          Discover  6011716359815938
# 999          Master Card          Citibank  5391458271565240
#
#     Card Holder's Name  CVV2 Issue Date Expiry Date  Billing Date  Card PIN  \
# 0        Frank Q Ortiz   362    09/2016     09/2034             7      1247
# 1      Tony E Martinez    35    06/2012     06/2030            23      6190
# ...

# %%
#show the ist ten records in the dataset
data.head(10)
# Out:
#    Card Type Full Name      Issuing Bank       Card Number  \
# 0                 Visa             Chase  4431465245886276
# 1             Discover          Discover  6224764404044446
# 2  Japan Credit Bureau               JCB  3541789329050940
# 3     American Express  American Express   371306399244328
# 4                 Visa             Chase  4332985341176660
# 5          Master Card             Chase  5405935391199277
# 6          Master Card              USAA  5359097928073131
# 7          Master Card   Bank of America  5230327834921460
# 8             Discover          Discover  6469129126918968
# 9             Discover          Discover  6011199663449639
#
#       Card Holder's Name  CVV2 Issue Date Expiry Date  Billing Date  Card PIN  \
# 0          Frank Q Ortiz   362    09/2016     09/2034             7      1247
# 1        Tony E Martinez    35    06/2012     06/2030            23      6190
# 2            Ana M Downs   945    03/2017     03/2021            10      8550
# ...

# %%
#show a summary of the columns their types and the non null count of each
data.info
# Out:
# <bound method DataFrame.info of      Card Type Full Name      Issuing Bank       Card Number  \
# 0                   Visa             Chase  4431465245886276
# 1               Discover          Discover  6224764404044446
# 2    Japan Credit Bureau               JCB  3541789329050940
# 3       American Express  American Express   371306399244328
# 4                   Visa             Chase  4332985341176660
# ..                   ...               ...               ...
# 995  Japan Credit Bureau               JCB  3548795949760431
# 996  Japan Credit Bureau               JCB  3566452282997041
# 997  Japan Credit Bureau               JCB  3539269980463108
# 998             Discover          Discover  6011716359815938
# 999          Master Card          Citibank  5391458271565240
#
#     Card Holder's Name  CVV2 Issue Date Expiry Date  Billing Date  Card PIN  \
# 0        Frank Q Ortiz   362    09/2016     09/2034             7      1247
# ...

# %%
#name the card type full name and the card holder name columns
data[["Card Type Full Name", "Card Holder's Name"]]
# Out:
#      Card Type Full Name Card Holder's Name
# 0                   Visa      Frank Q Ortiz
# 1               Discover    Tony E Martinez
# 2    Japan Credit Bureau        Ana M Downs
# 3       American Express     Calvin T House
# 4                   Visa       Gilda J Wade
# ..                   ...                ...
# 995  Japan Credit Bureau     Theresa F King
# 996  Japan Credit Bureau    Terence D Mejia
# 997  Japan Credit Bureau      Yolanda Moore
# 998             Discover     Kurtis V Haney
# 999          Master Card    Teresa Castillo
#
# [1000 rows x 2 columns]

# %%
#rename the card type full nmae and the card card holders name columns
#to 'Type and client respectively
data.rename(columns={'Card Type Full Name' : 'Type', 'Card Holder\'s Name': 'Clients'}, inplace=True)
#inplace true permanent false not
data.head(5)
# Out:
#                   Type      Issuing Bank       Card Number          Clients  \
# 0                 Visa             Chase  4431465245886276    Frank Q Ortiz
# 1             Discover          Discover  6224764404044446  Tony E Martinez
# 2  Japan Credit Bureau               JCB  3541789329050940      Ana M Downs
# 3     American Express  American Express   371306399244328   Calvin T House
# 4                 Visa             Chase  4332985341176660     Gilda J Wade
#
#    CVV2 Issue Date Expiry Date  Billing Date  Card PIN  Credit Limit
# 0   362    09/2016     09/2034             7      1247        103700
# 1    35    06/2012     06/2030            23      6190         92900
# 2   945    03/2017     03/2021            10      8550         71500
# 3  3868    09/2007     09/2018            26      1777        190500
# 4   237    12/2012     12/2023            26      5551        179700

# %%
#show card type bank client for all cases where credit limit > 70,000
data[data['Credit Limit'] > 70000][['Type', 'Clients']]
# Out:
#                     Type          Clients
# 0                   Visa    Frank Q Ortiz
# 1               Discover  Tony E Martinez
# 2    Japan Credit Bureau      Ana M Downs
# 3       American Express   Calvin T House
# 4                   Visa     Gilda J Wade
# ..                   ...              ...
# 995  Japan Credit Bureau   Theresa F King
# 996  Japan Credit Bureau  Terence D Mejia
# 997  Japan Credit Bureau    Yolanda Moore
# 998             Discover   Kurtis V Haney
# 999          Master Card  Teresa Castillo
#
# [708 rows x 2 columns]

# %%
#find all clients, billing date card no for clients of chase bank
#data[data['Issuing Bank'] == 'Chase Bank'][['Billing Date', 'Card Number', 'Clients']]

f=[(data['Issuing Bank'] == 'Chase Bank') ]
f[['Billing Date', 'Card Number', 'Clients']]
df[(df['Color'] == 'Silver') & (df['ListPrice'] > 350)]





#salaries[(salaries['BasePay'] > 80000) & (salaries['Agency'] == 'San Francisco')]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\juden\PYTH-3\Week-5\credit cards.ipynb Cell 7 in <cell line: 5>()
#       <a href='vscode-notebook-cell:/c%3A/Users/juden/PYTH-3/Week-5/credit%20cards.ipynb#ch0000006?line=0'>1</a> #find all clients, billing date card no for clients of chase bank
#       <a href='vscode-notebook-cell:/c%3A/Users/juden/PYTH-3/Week-5/credit%20cards.ipynb#ch0000006?line=1'>2</a> #data[data['Issuing Bank'] == 'Chase Bank'][['Billing Date', 'Card Number', 'Clients']]
#       <a href='vscode-notebook-cell:/c%3A/Users/juden/PYTH-3/Week-5/credit%20cards.ipynb#ch0000006?line=3'>4</a> f=[(data['Issuing Bank'] == 'Chase Bank') ]
# ----> <a href='vscode-notebook-cell:/c%3A/Users/juden/PYTH-3/Week-5/credit%20cards.ipynb#ch0000006?line=4'>5</a> f[['Billing Date', 'Card Number', 'Clients']]
# ...

# %%
#how many different card issuers are there?
data['Issuing Bank'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0                 Chase
# 1              Discover
# 2                   JCB
# 3      American Express
# 4                 Chase
#              ...
# 995                 JCB
# 996                 JCB
# 997                 JCB
# 998            Discover
# 999            Citibank
# Name: Issuing Bank, Length: 1000, dtype: object>

# %%
#show all clients card no credit card limit for visa and credit limit >100,000

data.groupby(['Type']).count()
# Out:
#                            Issuing Bank  Card Number  Clients  CVV2  \
# Type
# American Express                    151          151      151   151
# Diners Club International           164          164      164   164
# Discover                            130          130      130   130
# Japan Credit Bureau                 168          168      168   168
# Master Card                         198          198      198   198
# Visa                                189          189      189   189
#
#                            Issue Date  Expiry Date  Billing Date  Card PIN  \
# Type
# American Express                  151          151           151       151
# Diners Club International         164          164           164       164
# Discover                          130          130           130       130
# Japan Credit Bureau               168          168           168       168
# Master Card                       198          198           198       198
# ...

# %%
#get all clients issuing bank credit limit of all those thta are mastr card and expiry after 2020

data['Expiry Date'].str[-4:]
after_2020 = data[(data['Type'] == 'Master Card') & (data['Expiry Date'].apply(lambda x: x[3:]) >= '2021')]
after_2020[['Clients', 'Issuing Bank', 'Credit Limit']]
# Out:
#                    Clients     Issuing Bank  Credit Limit
# 6         Alvin M Espinoza             USAA         80600
# 7    Christopher X Holcomb  Bank of America         11000
# 13        Thomas L Stanton      Capital One         51800
# 15       Robert B Mcintyre            Chase         65900
# 20        Margery W Austin         Citibank        198800
# ..                     ...              ...           ...
# 944    Marcelino S Spencer      Capital One         84800
# 948         Neal A Everett  Bank of America        119000
# 955        Aaron X Coleman            Chase        175900
# 972    Federico X Chambers      Capital One        161200
# 987       Allen B Stafford            Chase         22900
#
# [120 rows x 3 columns]

# %%
#plot a bar chart showing the number of customers for each card type
import matplotlib.pyplot as plt
x = ['American Express','Diners Club International','Discover','Japan Credit Bureau','Master Card', 'Visa Card']
y = [151, 164, 130, 168, 198, 189]
width = 0.35       # the width of the bars: can also be len(x) sequence


fig, ax = plt.subplots()

ax.bar(x,y, width)
plt.show(block=True)

# %%
#plot a bar chart showing the number of customers for each card type
Client_data = data.groupby(['Type']).count()['Clients']

# %%
Client_data.unique()
# Out:
# array([151, 164, 130, 168, 198, 189], dtype=int64)

# %%
Client_data = data.groupby(['Type']).count()['Clients']

Client_data
# Out:
# Type
# American Express             151
# Diners Club International    164
# Discover                     130
# Japan Credit Bureau          168
# Master Card                  198
# Visa                         189
# Name: Clients, dtype: int64

# %%
data['Type'].value_counts()
# Out:
# Master Card                  198
# Visa                         189
# Japan Credit Bureau          168
# Diners Club International    164
# American Express             151
# Discover                     130
# Name: Type, dtype: int64

# %%
Client_data.index
# Out:
# Index(['American Express', 'Diners Club International', 'Discover',
#        'Japan Credit Bureau', 'Master Card', 'Visa'],
#       dtype='object', name='Type')

# %%
#Client_data.index, Client_data 0.3 width
import matplotlib.pyplot as plt 
width = 0.35 


fig, ax = plt.subplots()

ax.bar(Client_data.index, Client_data.unique(), width)
plt.show(block=True)
