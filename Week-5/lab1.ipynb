# %%
#import csv

#field_names = ['date', 'income description', 'expense description', 'income_amount', 'expense_amount']

#with open("journal entries.csv", 'w') as csvfile:
    #writer = csv.DictWriter(csvfile, fieldnames = field_names)
    #writer.writeheader()

print("Welcome to Budget Tracker")
print("Please choose from the following options: \n1. Add new entry to Budget_Tracker\n2. Display Total Account Balance\n3. View all Previous Entries")

option = int(input("Pls choose option 1 - 3:"))

if option == 1:
        print("Add New_entry to Budget_Tracker")
        
elif option == 2:
        print("Display Total Account balance")

elif option == 3:
        print("View all Previous Entries")
else:
        print("invalid entry, pls choose numbers 1-3")




class New_Entry():
    def __init__(self):
        self.date = []
        self.income = 0
        self.expenses = 0
        self.all_expense_entry = []
        self.expense_description = []
        self.income_description = []
        self.all_income_entry = []
        self.prompt_income()

    def date_ask(self):
        add_date = input('Enter the date of entry in MM-DD-YYYY format')
        return add_date

    def income_ask(self):
        add_income = input('Add income? [y/n]: ')
        return add_income

    def income_sum(self):
        self.income = sum(self.all_income_entry)

    def expense_ask(self):
        add_expense = input('Add expense? [y/n]: ')
        return add_expense

    def expense_sum(self):
        self.expenses = sum(self.all_expense_entry)

    def income_check(self):
        if not self.all_income_entry:
            print('Please enter atleast one source of income. ')
            self.prompt_income()
        else:
            return

    def expense_check(self):
        if not self.all_expense_entry:
            print('Please enter atleast one expense. ')
            self.prompt_expense()
        else:
            return

    def prompt_income(self):
        x = False
        while not x:
            result = self.income_ask()
            if result == 'y':
                income_input = float(input('Enter source of income. [Numbers Only]: '))
                self.all_income_entry.append(income_input)
                income_description = input('Enter income description. [Name Only]: ')
                self.income_description.append(income_description)
            else:
                self.income_check()
                
                self.prompt_expense()

    def prompt_expense(self):
        x = False
        while not x:
            result = self.expense_ask()
            if result == 'y':
                expense_input = float(input('Enter expense amount. [Numbers Only]: '))
                self.all_expense_entry.append(expense_input)
                expense_description = input('Enter expense name. [Name Only]: ')
                self.expense_description.append(expense_description)
            else:
                self.expense_check()

another = input('Would you like to run another analysis? [y/n]: ')
if another == 'y':
    print("please choose between options 1-3:......")


if option == 2:
    print("Display Total Account balance")
income = 
def user_balance(self):
        Balance = self.income - self.expenses
        
        
        another = input('Would you like to run another analysis? [y/n]: ')
        if another == 'y':
            #prompt = "choose" option
        else:
            self.close_program()

    

    def close_program(self):
        print('Exiting Program.')
        

if __name__ == '__main__':
    New_Entry()
# Out:
#   File <tokenize>:117
#     def close_program(self):
#     ^
# IndentationError: unindent does not match any outer indentation level
