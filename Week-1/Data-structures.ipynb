# %%
#lists
#zero indexed
#assign variable and start with empty list

names = []

days_of_week = ['Mon', 'Tue', 'Wed', 'Fri', 'Sat']

colors = list() #using the list constructor, also prints an empty list

#adding to a list

names.append('Pavel')
print(names)
names.append('Priscilla')
print(names)
names.append('Enzo')
names.append('Sanjeev')
names.append('Ella')
names.append('Sam')
print(names)

#number of names on list
num_of_names = len(names)
print(num_of_names)
print(len(names))

#remove gets rid of it but not return
#names.remove

#remove using pop removes and returns item at the end of the list

#names.pop()

print(names)

last_in_list = names.pop()
print(names)
print(last_in_list)

#remove form specific index
second_in_list = names.pop(1)
print(second_in_list)
print(names)

#insert, append adds to end only, we can insert any position
names.insert(1, second_in_list)
print(names)

#count the occurence of an item in a list

numbers = [1,2,3,4,5,3,-1,5]
number_of_5 = numbers.count(5)
print(number_of_5)

numbers.remove(2)
print(numbers)

#sum my numbers
total = sum(numbers)
print(total)
# Out:
# ['Pavel']
# ['Pavel', 'Priscilla']
# ['Pavel', 'Priscilla', 'Enzo', 'Sanjeev', 'Ella', 'Sam']
# 6
# 6
# ['Pavel', 'Priscilla', 'Enzo', 'Sanjeev', 'Ella', 'Sam']
# ['Pavel', 'Priscilla', 'Enzo', 'Sanjeev', 'Ella']
# Sam
# Priscilla
# ['Pavel', 'Enzo', 'Sanjeev', 'Ella']
# ['Pavel', 'Priscilla', 'Enzo', 'Sanjeev', 'Ella']
# 2
# [1, 3, 4, 5, 3, -1, 5]
# 20

# %%
#dictionaries
#a collection of key:value pairs

person = {} #an empty dictionary

city = dict() #an empty dictionary

car = {'make': 'Toyota', 'model': 'Corolla', 'year': '2020'}

#add to a dictionary

person['name'] = 'John'
print(person)
#add age to person
person['age'] = 30
print(person)
#keys in a dictionary are unique
#keys need to be immutable (primitive types - strings, floats, ints, boolean, etc...)
#lists and dictionaries CANNot b keys, because they are mutable
person['age'] = 28
print(person)

#name, age, address of each class person
class_list = []
class_list.append({
    'name': 'Pavel', 
    'age': '24', 
    'address': 'Toronto', 
    'pet':{ 
    'type': 'Dog', 
    'name':'Billy', 
    'age': '2'
}})
print(class_list)
class_list.append({'name': 'Priscilla', 'age': '30', 'address': 'Delta'})
class_list.append({'name': 'Enzo', 'age': '28', 'address': 'Ottawa'})
class_list.append({'name': 'Sanjeev', 'age': '27', 'address': 'NewYork'})
class_list.append({'name': 'Ella', 'age': '25', 'address': 'Touro'})
class_list.append({'name': 'Son', 'age': '23', 'address': 'Michigan'})
print(class_list)
print(class_list[-1]['age'])
print(class_list[0]['pet']['name'])
# Out:
# {'name': 'John'}
# {'name': 'John', 'age': 30}
# {'name': 'John', 'age': 28}
# [{'name': 'Pavel', 'age': '24', 'address': 'Toronto', 'pet': {'type': 'Dog', 'name': 'Billy', 'age': '2'}}]
# [{'name': 'Pavel', 'age': '24', 'address': 'Toronto', 'pet': {'type': 'Dog', 'name': 'Billy', 'age': '2'}}, {'name': 'Priscilla', 'age': '30', 'address': 'Delta'}, {'name': 'Enzo', 'age': '28', 'address': 'Ottawa'}, {'name': 'Sanjeev', 'age': '27', 'address': 'NewYork'}, {'name': 'Ella', 'age': '25', 'address': 'Touro'}, {'name': 'Son', 'age': '23', 'address': 'Michigan'}]
# 23
# Billy

# %%
#loop

my_string ='this is an arbituary string' 
#how would we find the number of vowels in this my_string

#1. put vowels in a list and store it in a variable
#2. iterate over the string , and check each letter in the string if it is in the list of vowels
#3.we need another variablee, so that each item one letter is a vowel we add 1 to this variable

vowels =['a', 'e', 'i', 'o', 'u' 'A', 'E','I','O','U']

#FOUR loop looks at each thing in that collection
